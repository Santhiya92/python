# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
covid_data=pd.read_csv("C:/Users/santh/Desktop/country_vaccinations.csv")

# %%
covid_data.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
covid_data.shape
# Out:
# (14230, 15)

# %%
covid_data.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %%
covid_data.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
covid_data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        8.486000e+03       7.850000e+03             5.732000e+03
# mean         4.611201e+06       3.001720e+06             1.467278e+06
# std          1.870498e+07       1.112719e+07             6.349924e+06
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          5.631175e+04       4.976875e+04             2.222525e+04
# 50%          3.977390e+05       3.100695e+05             1.619255e+05
# 75%          1.840986e+06       1.295492e+06             6.503910e+05
# max          2.359760e+08       1.417519e+08             9.674745e+07
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            7.101000e+03        1.403300e+04
# mean             1.296822e+05        7.496936e+04
# std              4.839956e+05        3.321700e+05
# min              0.000000e+00        0.000000e+00
# 25%              2.859000e+03        9.120000e+02
# ...

# %%
covid_data.isnull().sum()
# Out:
# country                                   0
# iso_code                                  0
# date                                      0
# total_vaccinations                     5744
# people_vaccinated                      6380
# people_fully_vaccinated                8498
# daily_vaccinations_raw                 7129
# daily_vaccinations                      197
# total_vaccinations_per_hundred         5744
# people_vaccinated_per_hundred          6380
# people_fully_vaccinated_per_hundred    8498
# daily_vaccinations_per_million          197
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
covid_data["country"].value_counts()
# Out:
# Canada           135
# China            134
# Russia           134
# Israel           130
# United States    129
#                 ...
# Ethiopia           1
# Djibouti           1
# Libya              1
# Congo              1
# Armenia            1
# Name: country, Length: 193, dtype: int64

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14230 entries, 0 to 14229
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              14230 non-null  object
#  1   iso_code                             14230 non-null  object
#  2   date                                 14230 non-null  object
#  3   total_vaccinations                   8486 non-null   float64
#  4   people_vaccinated                    7850 non-null   float64
#  5   people_fully_vaccinated              5732 non-null   float64
#  6   daily_vaccinations_raw               7101 non-null   float64
#  7   daily_vaccinations                   14033 non-null  float64
#  8   total_vaccinations_per_hundred       8486 non-null   float64
#  9   people_vaccinated_per_hundred        7850 non-null   float64
#  10  people_fully_vaccinated_per_hundred  5732 non-null   float64
# ...

# %%
covid_data.tail(5)
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 14225  Zimbabwe      ZWE  2021-04-23            365985.0           319732.0
# 14226  Zimbabwe      ZWE  2021-04-24            372099.0           324488.0
# 14227  Zimbabwe      ZWE  2021-04-25            390018.0           336600.0
# 14228  Zimbabwe      ZWE  2021-04-26            411610.0           353834.0
# 14229  Zimbabwe      ZWE  2021-04-27            433939.0           370676.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 14225                  46253.0                 14186.0              8755.0
# 14226                  47611.0                  6114.0              8600.0
# 14227                  53418.0                 17919.0             10796.0
# 14228                  57776.0                 21592.0             13517.0
# 14229                  63263.0                 22329.0             15562.0
#
# ...

# %%
covid_data.isnull()
# Out:
#        country  iso_code   date  total_vaccinations  people_vaccinated  \
# 0        False     False  False               False              False
# 1        False     False  False                True               True
# 2        False     False  False                True               True
# 3        False     False  False                True               True
# 4        False     False  False                True               True
# ...        ...       ...    ...                 ...                ...
# 14225    False     False  False               False              False
# 14226    False     False  False               False              False
# 14227    False     False  False               False              False
# 14228    False     False  False               False              False
# 14229    False     False  False               False              False
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
covid_data["total_vaccinations"].replace(np.nan,0, inplace=True)

# %%
covid_data["total_vaccinations"].isnull().sum()
# Out:
# 0

# %%
covid_data.head(10)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 0.0                NaN
# 2  Afghanistan      AFG  2021-02-24                 0.0                NaN
# 3  Afghanistan      AFG  2021-02-25                 0.0                NaN
# 4  Afghanistan      AFG  2021-02-26                 0.0                NaN
# 5  Afghanistan      AFG  2021-02-27                 0.0                NaN
# 6  Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7  Afghanistan      AFG  2021-03-01                 0.0                NaN
# 8  Afghanistan      AFG  2021-03-02                 0.0                NaN
# 9  Afghanistan      AFG  2021-03-03                 0.0                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
covid_data.fillna(0.0, inplace=True)

# %%
covid_data.head(10)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 0.0                0.0
# 2  Afghanistan      AFG  2021-02-24                 0.0                0.0
# 3  Afghanistan      AFG  2021-02-25                 0.0                0.0
# 4  Afghanistan      AFG  2021-02-26                 0.0                0.0
# 5  Afghanistan      AFG  2021-02-27                 0.0                0.0
# 6  Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7  Afghanistan      AFG  2021-03-01                 0.0                0.0
# 8  Afghanistan      AFG  2021-03-02                 0.0                0.0
# 9  Afghanistan      AFG  2021-03-03                 0.0                0.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
vaccine= covid_data.groupby("country")["vaccines"].unique()

# %%
vaccine.tail()
# Out:
# country
# Venezuela                                       [Sputnik V]
# Vietnam                                [Oxford/AstraZeneca]
# Wales        [Moderna, Oxford/AstraZeneca, Pfizer/BioNTech]
# Zambia                                 [Oxford/AstraZeneca]
# Zimbabwe                                [Sinopharm/Beijing]
# Name: vaccines, dtype: object

# %%
sortedTotalVaccinations = covid_data.sort_values(by=['total_vaccinations'], ascending=False)
sortedTotalVaccinations.head()
# Out:
#              country iso_code        date  total_vaccinations  \
# 2671           China      CHN  2021-04-27         235976000.0
# 13841  United States      USA  2021-04-27         232407669.0
# 13840  United States      USA  2021-04-26         230768454.0
# 2670           China      CHN  2021-04-26         229489000.0
# 13839  United States      USA  2021-04-25         228661408.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 2671                 0.0                      0.0               6487000.0
# 13841        141751857.0               96747454.0               1639215.0
# 13840        140969663.0               95888088.0               2107046.0
# 2670                 0.0                      0.0               4588000.0
# 13839        139978480.0               94772329.0               3020948.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 2671            5289429.0                           16.39
# ...

# %%
vac_per=covid_data.groupby("country")["people_vaccinated","people_fully_vaccinated"].max()
vac_per.tail()
# Out:
# <ipython-input-21-a620606398dc>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   vac_per=covid_data.groupby("country")["people_vaccinated","people_fully_vaccinated"].max()
#            people_vaccinated  people_fully_vaccinated
# country
# Venezuela           250000.0                      0.0
# Vietnam             318792.0                      0.0
# Wales              1785347.0                 701099.0
# Zambia               14012.0                      0.0
# Zimbabwe            370676.0                  63263.0

# %%
#Which country has vaccinated more people?
#Country vs Total Vaccination

df1=covid_data.groupby("country")["total_vaccinations"].max()
df1.head()
# Out:
# country
# Afghanistan    240000.0
# Albania        400064.0
# Algeria         75000.0
# Andorra         26414.0
# Angola         456349.0
# Name: total_vaccinations, dtype: float64

# %%
#Country vs people fully vaccinated
df2=covid_data.groupby("country")["people_fully_vaccinated"].max()
df2.head()
# Out:
# country
# Afghanistan       0.0
# Albania         655.0
# Algeria           0.0
# Andorra        4681.0
# Angola            0.0
# Name: people_fully_vaccinated, dtype: float64

# %%
df2.head(5).plot(kind='barh')
plt.title("Country vs people fully vaccinated")
plt.ylabel("people_fully_vaccinated")
plt.xlabel("country")

plt.show()

# %%
#Find the average vaccination per day in the country?
#Average daily vaccinations by country - Top 10

# %%
df4=pd.read_csv("C:/Users/santh/Desktop/countryContinent.csv")

# %%
df4.head()
# Out:
#           country code_2 code_3  country_code     iso_3166_2 continent  \
# 0     Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1   Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2         Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3         Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4  American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
#
#         sub_region  region_code  sub_region_code
# 0    Southern Asia        142.0             34.0
# 1  Northern Europe        150.0            154.0
# 2  Southern Europe        150.0             39.0
# 3  Northern Africa          2.0             15.0
# 4        Polynesia          9.0             61.0

# %%
df5=covid
# Out:
# country             object
# code_2              object
# code_3              object
# country_code         int64
# iso_3166_2          object
# continent           object
# sub_region          object
# region_code        float64
# sub_region_code    float64
# dtype: object

# %%
df5.head(100)
# Out:
# 0         Asia
# 1       Europe
# 2       Europe
# 3       Africa
# 4      Oceania
#         ...
# 244    Oceania
# 245     Africa
# 246       Asia
# 247     Africa
# 248     Africa
# Name: continent, Length: 249, dtype: object

# %%
merge=covid_data.
